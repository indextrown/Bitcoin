# %% [markdown]
# ## RSI 봇 백테스팅

# %%
# import pyupbit
# import pandas as pd
# from datetime import datetime
# import matplotlib.pyplot as plt
# import matplotlib as mpl
# import numpy as np
# import time

# mpl.rcParams['font.family'] = 'AppleGothic'
# mpl.rcParams['axes.unicode_minus'] = False

# # ======================
# # 🔹 설정값
# ticker = "KRW-BTC"
# start_date = "2025-05-01"
# interval = "minute240"
# bot_interval = 30
# fee = 0.0005
# initial_capital = 3_000_000
# min_trade = 5000

# # 🔹 RSI 및 수익률 조건
# rsi_buy_threshold = 25
# rsi_sell_threshold = 70
# min_profit_to_sell = 7  # ✔️ 300% 이상일 때만 매도
# # ======================

# # 1️⃣ OHLCV 데이터 수집
# all_data = []
# to = datetime.now()

# while True:
#     data = pyupbit.get_ohlcv(ticker, interval=interval, to=to, count=200)
#     print(f"Fetching data until {to}")
#     if data is None or data.empty:
#         break
#     all_data.append(data)
#     to = data.index[0]
#     if to < pd.to_datetime(start_date):
#         break
#     time.sleep(0.3)

# df = pd.concat(all_data)
# df = df[df.index >= pd.to_datetime(start_date)]
# df.sort_index(inplace=True)

# # 2️⃣ RSI 계산
# delta = df["close"].diff()
# gain = np.where(delta > 0, delta, 0)
# loss = np.where(delta < 0, -delta, 0)

# roll_up = pd.Series(gain).rolling(window=14).mean()
# roll_down = pd.Series(loss).rolling(window=14).mean()

# RS = roll_up / roll_down
# RSI = 100.0 - (100.0 / (1.0 + RS))
# df["RSI14"] = RSI.values

# # 3️⃣ RSI 시각화
# plt.figure(figsize=(15,8))
# plt.subplot(2,1,1)
# plt.plot(df.index, df["close"], label=f"{ticker} (Close)")
# plt.title(f"{ticker} {interval} + RSI14 ({start_date} ~ Now)")
# plt.ylabel("Price (KRW)")
# plt.legend()
# plt.grid(True)

# plt.subplot(2,1,2)
# plt.plot(df.index, df["RSI14"], color="red", label="RSI 14", linewidth=0.2)
# plt.axhline(rsi_sell_threshold, color="gray", linestyle="--", linewidth=1)
# plt.axhline(rsi_buy_threshold, color="gray", linestyle="--", linewidth=1)

# oversold = df[df["RSI14"] <= rsi_buy_threshold]
# overbought = df[df["RSI14"] >= rsi_sell_threshold]

# plt.scatter(oversold.index, oversold["RSI14"], color="blue", s=40, zorder=5, label=f"RSI ≤ {rsi_buy_threshold}")
# plt.scatter(overbought.index, overbought["RSI14"], color="red", s=40, zorder=5, label=f"RSI ≥ {rsi_sell_threshold}")

# plt.ylabel("RSI")
# plt.xlabel("Date")
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# # ✅ 상태 출력
# print("\n📌 [RSI 실시간 확인]")
# print(f" - 최신 캔들 시작 시간: {df.index[-1]}")
# print(f" - 현재 RSI14 값: {df['RSI14'].iloc[-1]:.2f}")
# print(f" - 참고용 이전 RSI 값: {df['RSI14'].iloc[-2]:.2f}")

# print("\n" + "="*50)
# print("📌 [시뮬레이션 전략 요약]")
# print(f"- 매수 조건:")
# print(f"   └ RSI ≤ {rsi_buy_threshold} ➜ 현금의 20% 분할 매수 (단, {min_trade:,}원 이상일 때만)")
# print(f"- 매도 조건:")
# print(f"   └ RSI ≥ {rsi_sell_threshold} AND 수익률 ≥ {min_profit_to_sell}% ➜ 보유량의 절반 익절")
# print(f"   └ 그 외 ➜ 보유 유지 (매도하지 않음)")
# print("="*50)

# # ======================
# # 4️⃣ 매매 시뮬레이션
# capital = initial_capital
# position = 0
# avg_buy_price = 0

# for i in range(1, len(df)):
#     prev_rsi = df["RSI14"].iloc[i - 1]
#     rsi = df["RSI14"].iloc[i]
#     price = df["close"].iloc[i]

#     # ✅ [매수 조건]
#     if prev_rsi <= rsi_buy_threshold and rsi > rsi_buy_threshold and capital > 0:
#         invest_amount = capital * 0.2
#         if invest_amount < min_trade:
#             continue
#         btc_amount = (invest_amount * (1 - fee)) / price
#         total_cost = (avg_buy_price * position) + invest_amount
#         position += btc_amount
#         avg_buy_price = total_cost / position
#         capital -= invest_amount
#         print(f"{df.index[i]} 매수: {price:.0f}원 | 매수 금액: {invest_amount:.0f}원 | 평균 단가: {avg_buy_price:.0f}원 | 잔여 현금: {capital:.0f}원")

#     # ✅ [매도 조건]
#     if rsi >= rsi_sell_threshold and position > 0 and avg_buy_price > 0:
#         profit_rate = (price - avg_buy_price) / avg_buy_price * 100

#         if profit_rate >= min_profit_to_sell:
#             hold_value = position * price
#             if hold_value < min_trade:
#                 continue

#             sell_amount = position / 2
#             sell_value = (sell_amount * price) * (1 - fee)
#             if sell_value < min_trade:
#                 continue
#             capital += sell_value
#             position -= sell_amount
#             print(f"{df.index[i]} ✅ 절반 매도(익절): {price:.0f}원 | 매도 금액: {sell_value:,.0f}원 | 남은 보유량: {position:.6f} | 수익률: {profit_rate:.2f}%")

# # 5️⃣ 정산 출력
# final_price = df["close"].iloc[-1]
# btc_value = position * final_price
# final_value = capital + btc_value
# total_profit_rate = (final_value - initial_capital) / initial_capital * 100

# print("="*50)
# print("📦 최종 자산 내역")
# print(f" - 보유 현금: {capital:,.0f} 원")
# print(f" - 보유 BTC 수량: {position:.6f} BTC")
# print(f" - BTC 평가 금액: {btc_value:,.0f} 원 (가격: {final_price:,.0f} 원)")
# print("-" * 50)
# print(f"💰 총 평가 금액: {final_value:,.0f} 원")
# print(f"📈 총 수익률: {total_profit_rate:.2f}%")
# print("="*50)
# Out:
# Fetching data until 2025-08-24 20:37:34.092285
# Fetching data until 2025-07-22 13:00:00
# Fetching data until 2025-06-19 17:00:00
# Fetching data until 2025-05-17 21:00:00
# ERROR:tornado.application:Exception in callback functools.partial(<bound method OutStream._flush of <ipykernel.iostream.OutStream object at 0x1098a40d0>>)
# Traceback (most recent call last):
#   File "/Users/kimdonghyeon/2025/개발/python/비트코인강의/.venv/lib/python3.9/site-packages/jupyter_client/session.py", line 95, in json_packer
#     return json.dumps(
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 30-31: surrogates not allowed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimdonghyeon/2025/개발/python/비트코인강의/.venv/lib/python3.9/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/Users/kimdonghyeon/2025/개발/python/비트코인강의/.venv/lib/python3.9/site-packages/ipykernel/iostream.py", line 649, in _flush
#     self.session.send(
#   File "/Users/kimdonghyeon/2025/개발/python/비트코인강의/.venv/lib/python3.9/site-packages/jupyter_client/session.py", line 852, in send
#     to_send = self.serialize(msg, ident)
#   File "/Users/kimdonghyeon/2025/개발/python/비트코인강의/.venv/lib/python3.9/site-packages/jupyter_client/session.py", line 721, in serialize
#     content = self.pack(content)
#   File "/Users/kimdonghyeon/2025/개발/python/비트코인강의/.venv/lib/python3.9/site-packages/jupyter_client/session.py", line 103, in json_packer
#     packed = json.dumps(
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 30-31: surrogates not allowed

# %%
import pyupbit
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import time

mpl.rcParams['font.family'] = 'AppleGothic'
mpl.rcParams['axes.unicode_minus'] = False

# ======================
# 설정값
ticker = "KRW-BTC"
start_date = "2025-05-01"
interval = "minute60"  # 캔들 간격
bot_interval = 30  # 봇 실행 주기 (분 단위)
fee = 0.0005
initial_capital = 3_000_000
min_trade = 5000

# RSI 및 수익률 조건
rsi_buy_threshold = 25
rsi_sell_threshold = 70
min_profit_to_sell = 7
# ======================

# 1. OHLCV 데이터 수집
to = datetime.now()
all_data = []

while True:
    data = pyupbit.get_ohlcv(ticker, interval=interval, to=to, count=200)
    print(f"Fetching data until {to}")
    if data is None or data.empty:
        break
    all_data.append(data)
    to = data.index[0]
    if to < pd.to_datetime(start_date):
        break
    time.sleep(0.3)

df = pd.concat(all_data)
df = df[df.index >= pd.to_datetime(start_date)]
df = df[~df.index.duplicated(keep='first')]  # 인덱스 중복 제거
df.sort_index(inplace=True)

# 2. RSI 계산
delta = df["close"].diff()
gain = np.where(delta > 0, delta, 0)
loss = np.where(delta < 0, -delta, 0)

roll_up = pd.Series(gain).rolling(window=14).mean()
roll_down = pd.Series(loss).rolling(window=14).mean()

RS = roll_up / roll_down
RSI = 100.0 - (100.0 / (1.0 + RS))
df["RSI14"] = RSI.values

# 3. RSI 시각화
plt.figure(figsize=(15,8))
plt.subplot(2,1,1)
plt.plot(df.index, df["close"], label=f"{ticker} (Close)")
plt.title(f"{ticker} {interval} + RSI14 ({start_date} ~ Now)")
plt.ylabel("Price (KRW)")
plt.legend()
plt.grid(True)

plt.subplot(2,1,2)
plt.plot(df.index, df["RSI14"], color="red", label="RSI 14", linewidth=0.5)
plt.axhline(rsi_sell_threshold, color="gray", linestyle="--", linewidth=1)
plt.axhline(rsi_buy_threshold, color="gray", linestyle="--", linewidth=1)

oversold = df[df["RSI14"] <= rsi_buy_threshold]
overbought = df[df["RSI14"] >= rsi_sell_threshold]

plt.scatter(oversold.index, oversold["RSI14"], color="blue", s=40, zorder=5, label=f"RSI ≤ {rsi_buy_threshold}")
plt.scatter(overbought.index, overbought["RSI14"], color="red", s=40, zorder=5, label=f"RSI ≥ {rsi_sell_threshold}")

plt.ylabel("RSI")
plt.xlabel("Date")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 상태 출력
print("\n[RSI 실시간 확인]")
print(f" - 최신 캐들 시작 시간: {df.index[-1]}")
print(f" - 현재 RSI14 값: {df['RSI14'].iloc[-1]:.2f}")
print(f" - 참고용 이전 RSI 값: {df['RSI14'].iloc[-2]:.2f}")
print(f"🗓 분석 기간: {df.index[0].strftime('%Y-%m-%d')} ~ {df.index[-1].strftime('%Y-%m-%d')} ({num_days}일)")

print("\n" + "="*50)
print("[시뮬리언 전략 요조]")
print(f"- 매수 조건:")
print(f"   └ RSI ≤ {rsi_buy_threshold} ➔ 현금의 20% 분할 매수 (단, {min_trade:,}원 이상일 때만)")
print(f"- 매도 조건:")
print(f"   └ RSI ≥ {rsi_sell_threshold} AND 수익률 ≥ {min_profit_to_sell}% ➔ 보유량의 절마리 익절")
print(f"   └ 그 외 ➔ 보유 유지 (매도하지 않음)")
print(f"- 보트 실행 주기: {bot_interval}분 간격")
print("="*50)

# 4. 매매 시뮬리언
capital = initial_capital
position = 0
avg_buy_price = 0
bot_interval_timedelta = timedelta(minutes=bot_interval)

start_time = df.index[0]
end_time = df.index[-1]
bot_times = pd.date_range(start=start_time, end=end_time, freq=f"{bot_interval}min")

timestamps = df.index

executions = 0

for current_time in bot_times:
    idx_arr = timestamps.get_indexer([current_time], method="ffill")
    if idx_arr[0] == -1:
        continue
    idx = idx_arr[0]
    if idx == 0 or idx >= len(df):
        continue

    executions += 1

    prev_rsi = df["RSI14"].iloc[idx - 1]
    rsi = df["RSI14"].iloc[idx]
    price = df["close"].iloc[idx]

    if prev_rsi <= rsi_buy_threshold and rsi > rsi_buy_threshold and capital > 0:
        invest_amount = capital * 0.2
        if invest_amount < min_trade:
            continue
        btc_amount = (invest_amount * (1 - fee)) / price
        total_cost = (avg_buy_price * position) + invest_amount
        position += btc_amount
        avg_buy_price = total_cost / position
        capital -= invest_amount
        print(f"{df.index[idx]} 매수: {price:.0f}원 | 매수 금액: {invest_amount:.0f}원 | 평균 단가: {avg_buy_price:.0f}원 | 잔여 현금: {capital:.0f}원")

    if rsi >= rsi_sell_threshold and position > 0 and avg_buy_price > 0:
        profit_rate = (price - avg_buy_price) / avg_buy_price * 100

        if profit_rate >= min_profit_to_sell:
            hold_value = position * price
            if hold_value < min_trade:
                continue

            sell_amount = position / 2
            sell_value = (sell_amount * price) * (1 - fee)
            if sell_value < min_trade:
                continue
            capital += sell_value
            position -= sell_amount
            print(f"{df.index[idx]} 절마리 매도(익절): {price:.0f}원 | 매도 금액: {sell_value:,.0f}원 | 남은 보유량: {position:.6f} | 수익률: {profit_rate:.2f}%")

# 5. 정산 출력
final_price = df["close"].iloc[-1]
btc_value = position * final_price
final_value = capital + btc_value
total_profit_rate = (final_value - initial_capital) / initial_capital * 100
num_days = (df.index[-1] - df.index[0]).days + 1

print("="*50)
print("[최종 자산 내역]")
print(f" - 보유 현금: {capital:,.0f} 원")
print(f" - 보유 BTC 수량: {position:.6f} BTC")
print(f" - BTC 평가 금액: {btc_value:,.0f} 원 (가격: {final_price:,.0f} 원)")
print("-" * 50)
print(f"💰 총 평가 금액: {final_value:,.0f} 원")
print(f"📈 총 수익률: {total_profit_rate:.2f}%")
print(f"🕒 총 실행 횟수: {executions}회 (보트 인터벌: {bot_interval}분)")
print("="*50)
# Out:
# Fetching data until 2025-08-24 23:05:50.035056
# Fetching data until 2025-08-16 16:00:00
# Fetching data until 2025-08-08 17:00:00
# Fetching data until 2025-07-31 18:00:00
# Fetching data until 2025-07-23 19:00:00
# Fetching data until 2025-07-15 20:00:00
# Fetching data until 2025-07-07 21:00:00
# Fetching data until 2025-06-29 18:00:00
# Fetching data until 2025-06-21 19:00:00
# Fetching data until 2025-06-13 20:00:00
# Fetching data until 2025-06-05 21:00:00
# Fetching data until 2025-05-28 22:00:00
# Fetching data until 2025-05-20 23:00:00
# Fetching data until 2025-05-13 00:00:00
# Fetching data until 2025-05-05 01:00:00
# [RSI 실시간 확인]
#  - 최신 캐들 시작 시간: 2025-08-24 23:00:00
#  - 현재 RSI14 값: 28.00
#  - 참고용 이전 RSI 값: 40.94
# 🗓 분석 기간: 2025-05-01 ~ 2025-08-24 (116일)
#
# ==================================================
# [시뮬리언 전략 요조]
# - 매수 조건:
#    └ RSI ≤ 25 ➔ 현금의 20% 분할 매수 (단, 5,000원 이상일 때만)
# - 매도 조건:
#    └ RSI ≥ 70 AND 수익률 ≥ 7% ➔ 보유량의 절마리 익절
#    └ 그 외 ➔ 보유 유지 (매도하지 않음)
# - 보트 실행 주기: 30분 간격
# ==================================================
# 2025-05-05 21:00:00 매수: 133669000원 | 매수 금액: 600000원 | 평균 단가: 133735868원 | 잔여 현금: 2400000원
# 2025-05-05 21:00:00 매수: 133669000원 | 매수 금액: 480000원 | 평균 단가: 133735868원 | 잔여 현금: 1920000원
# 2025-05-06 23:00:00 매수: 133892000원 | 매수 금액: 384000원 | 평균 단가: 133794317원 | 잔여 현금: 1536000원
# 2025-05-06 23:00:00 매수: 133892000원 | 매수 금액: 307200원 | 평균 단가: 133822847원 | 잔여 현금: 1228800원
# 2025-05-09 05:00:00 절마리 매도(익절): 143999000원 | 매도 금액: 952,466원 | 남은 보유량: 0.006618 | 수익률: 7.60%
# 2025-05-09 05:00:00 절마리 매도(익절): 143999000원 | 매도 금액: 476,233원 | 남은 보유량: 0.003309 | 수익률: 7.60%
# 2025-05-09 06:00:00 절마리 매도(익절): 143997000원 | 매도 금액: 238,113원 | 남은 보유량: 0.001654 | 수익률: 7.60%
# 2025-05-09 06:00:00 절마리 매도(익절): 143997000원 | 매도 금액: 119,057원 | 남은 보유량: 0.000827 | 수익률: 7.60%
# 2025-05-09 07:00:00 절마리 매도(익절): 144452000원 | 매도 금액: 59,716원 | 남은 보유량: 0.000414 | 수익률: 7.94%
# 2025-05-09 07:00:00 절마리 매도(익절): 144452000원 | 매도 금액: 29,858원 | 남은 보유량: 0.000207 | 수익률: 7.94%
# 2025-05-09 08:00:00 절마리 매도(익절): 144780000원 | 매도 금액: 14,963원 | 남은 보유량: 0.000103 | 수익률: 8.19%
# 2025-05-09 08:00:00 절마리 매도(익절): 144780000원 | 매도 금액: 7,482원 | 남은 보유량: 0.000052 | 수익률: 8.19%
# 2025-05-14 19:00:00 매수: 145272000원 | 매수 금액: 625338원 | 평균 단가: 145207863원 | 잔여 현금: 2501351원
# 2025-05-14 19:00:00 매수: 145272000원 | 매수 금액: 500270원 | 평균 단가: 145268264원 | 잔여 현금: 2001081원
# 2025-05-19 22:00:00 매수: 146692000원 | 매수 금액: 400216원 | 평균 단가: 145656224원 | 잔여 현금: 1600864원
# 2025-05-19 22:00:00 매수: 146692000원 | 매수 금액: 320173원 | 평균 단가: 145846680원 | 잔여 현금: 1280692원
# 2025-05-23 22:00:00 매수: 152442000원 | 매수 금액: 256138원 | 평균 단가: 146625619원 | 잔여 현금: 1024553원
# 2025-05-23 22:00:00 매수: 152442000원 | 매수 금액: 204911원 | 평균 단가: 147128997원 | 잔여 현금: 819643원
# 2025-05-25 21:00:00 매수: 150531000원 | 매수 금액: 163929원 | 평균 단가: 147354076원 | 잔여 현금: 655714원
# 2025-05-25 21:00:00 매수: 150531000원 | 매수 금액: 131143원 | 평균 단가: 147514192원 | 잔여 현금: 524571원
# 2025-05-29 05:00:00 매수: 150060000원 | 매수 금액: 104914원 | 평균 단가: 147613807원 | 잔여 현금: 419657원
# 2025-05-29 05:00:00 매수: 150060000원 | 매수 금액: 83931원 | 평균 단가: 147688208원 | 잔여 현금: 335726원
# 2025-05-30 10:00:00 매수: 147910000원 | 매수 금액: 67145원 | 평균 단가: 147695126원 | 잔여 현금: 268580원
# 2025-05-30 10:00:00 매수: 147910000원 | 매수 금액: 53716원 | 평균 단가: 147700432원 | 잔여 현금: 214864원
# 2025-06-02 23:00:00 매수: 146620000원 | 매수 금액: 42973원 | 평균 단가: 147685721원 | 잔여 현금: 171892원
# 2025-06-02 23:00:00 매수: 146620000원 | 매수 금액: 34378원 | 평균 단가: 147674258원 | 잔여 현금: 137513원
# 2025-06-04 22:00:00 매수: 145793000원 | 매수 금액: 27503원 | 평균 단가: 147657608원 | 잔여 현금: 110011원
# 2025-06-04 22:00:00 매수: 145793000원 | 매수 금액: 22002원 | 평균 단가: 147644506원 | 잔여 현금: 88008원
# 2025-06-12 23:00:00 매수: 147773000원 | 매수 금액: 17602원 | 평균 단가: 147645668원 | 잔여 현금: 70407원
# 2025-06-12 23:00:00 매수: 147773000원 | 매수 금액: 14081원 | 평균 단가: 147646587원 | 잔여 현금: 56325원
# 2025-06-15 00:00:00 매수: 145550000원 | 매수 금액: 11265원 | 평균 단가: 147639104원 | 잔여 현금: 45060원
# 2025-06-15 00:00:00 매수: 145550000원 | 매수 금액: 9012원 | 평균 단가: 147633157원 | 잔여 현금: 36048원
# 2025-06-17 22:00:00 매수: 145516000원 | 매수 금액: 7210원 | 평균 단가: 147628343원 | 잔여 현금: 28839원
# 2025-06-17 22:00:00 매수: 145516000원 | 매수 금액: 5768원 | 평균 단가: 147624508원 | 잔여 현금: 23071원
# 2025-07-11 11:00:00 절마리 매도(익절): 158508000원 | 매도 금액: 1,669,094원 | 남은 보유량: 0.010535 | 수익률: 7.37%
# 2025-07-11 11:00:00 절마리 매도(익절): 158508000원 | 매도 금액: 834,547원 | 남은 보유량: 0.005268 | 수익률: 7.37%
# 2025-07-11 12:00:00 절마리 매도(익절): 158642000원 | 매도 금액: 417,626원 | 남은 보유량: 0.002634 | 수익률: 7.46%
# 2025-07-11 12:00:00 절마리 매도(익절): 158642000원 | 매도 금액: 208,813원 | 남은 보유량: 0.001317 | 수익률: 7.46%
# 2025-07-11 13:00:00 절마리 매도(익절): 158696000원 | 매도 금액: 104,442원 | 남은 보유량: 0.000658 | 수익률: 7.50%
# 2025-07-11 13:00:00 절마리 매도(익절): 158696000원 | 매도 금액: 52,221원 | 남은 보유량: 0.000329 | 수익률: 7.50%
# 2025-07-11 14:00:00 절마리 매도(익절): 159621000원 | 매도 금액: 26,263원 | 남은 보유량: 0.000165 | 수익률: 8.13%
# 2025-07-11 14:00:00 절마리 매도(익절): 159621000원 | 매도 금액: 13,131원 | 남은 보유량: 0.000082 | 수익률: 8.13%
# 2025-07-11 15:00:00 절마리 매도(익절): 159241000원 | 매도 금액: 6,550원 | 남은 보유량: 0.000041 | 수익률: 7.87%
# 2025-07-15 13:00:00 매수: 160757000원 | 매수 금액: 671152원 | 평균 단가: 160708383원 | 잔여 현금: 2684607원
# 2025-07-15 13:00:00 매수: 160757000원 | 매수 금액: 536921원 | 평균 단가: 160765420원 | 잔여 현금: 2147686원
# 2025-07-15 21:00:00 매수: 160504000원 | 매수 금액: 429537원 | 평균 단가: 160718047원 | 잔여 현금: 1718148원
# 2025-07-15 21:00:00 매수: 160504000원 | 매수 금액: 343630원 | 평균 단가: 160694903원 | 잔여 현금: 1374519원
# 2025-07-23 23:00:00 매수: 160858000원 | 매수 금액: 274904원 | 평균 단가: 160724462원 | 잔여 현금: 1099615원
# 2025-07-23 23:00:00 매수: 160858000원 | 매수 금액: 219923원 | 평균 단가: 160743401원 | 잔여 현금: 879692원
# 2025-07-25 18:00:00 매수: 158824000원 | 매수 금액: 175938원 | 평균 단가: 160620298원 | 잔여 현금: 703754원
# 2025-07-25 18:00:00 매수: 158824000원 | 매수 금액: 140751원 | 평균 단가: 160533074원 | 잔여 현금: 563003원
# 2025-08-01 10:00:00 매수: 160493000원 | 매수 금액: 112601원 | 평균 단가: 160534629원 | 잔여 현금: 450402원
# 2025-08-01 10:00:00 매수: 160493000원 | 매수 금액: 90080원 | 평균 단가: 160535789원 | 잔여 현금: 360322원
# 2025-08-01 18:00:00 매수: 160391000원 | 매수 금액: 72064원 | 평균 단가: 160534275원 | 잔여 현금: 288257원
# 2025-08-01 18:00:00 매수: 160391000원 | 매수 금액: 57651원 | 평균 단가: 160533114원 | 잔여 현금: 230606원
# 2025-08-15 03:00:00 매수: 164191000원 | 매수 금액: 46121원 | 평균 단가: 160586184원 | 잔여 현금: 184485원
# 2025-08-15 03:00:00 매수: 164191000원 | 매수 금액: 36897원 | 평균 단가: 160627568원 | 잔여 현금: 147588원
# 2025-08-16 01:00:00 매수: 164065000원 | 매수 금액: 29518원 | 평균 단가: 160658914원 | 잔여 현금: 118070원
# 2025-08-16 01:00:00 매수: 164065000원 | 매수 금액: 23614원 | 평균 단가: 160683592원 | 잔여 현금: 94456원
# 2025-08-18 21:00:00 매수: 160857000원 | 매수 금액: 18891원 | 평균 단가: 160685049원 | 잔여 현금: 75565원
# 2025-08-18 21:00:00 매수: 160857000원 | 매수 금액: 15113원 | 평균 단가: 160686203원 | 잔여 현금: 60452원
# 2025-08-20 02:00:00 매수: 158582000원 | 매수 금액: 12090원 | 평균 단가: 160678720원 | 잔여 현금: 48362원
# 2025-08-20 02:00:00 매수: 158582000원 | 매수 금액: 9672원 | 평균 단가: 160672774원 | 잔여 현금: 38689원
# 2025-08-20 05:00:00 매수: 158936000원 | 매수 금액: 7738원 | 평균 단가: 160668884원 | 잔여 현금: 30951원
# 2025-08-20 05:00:00 매수: 158936000원 | 매수 금액: 6190원 | 평균 단가: 160665785원 | 잔여 현금: 24761원
# ==================================================
# [최종 자산 내역]
#  - 보유 현금: 24,761 원
#  - 보유 BTC 수량: 0.020770 BTC
#  - BTC 평가 금액: 3,307,126 원 (가격: 159,224,000 원)
# --------------------------------------------------
# 💰 총 평가 금액: 3,331,888 원
# 📈 총 수익률: 11.06%
# 🕒 총 실행 횟수: 5565회 (보트 인터벌: 30분)
# ==================================================
